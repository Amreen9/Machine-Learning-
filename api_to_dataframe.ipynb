# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=61edce02e942091acaf4ea3adf20e348&language=en-US&page=1')

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df.head()
# Out:
#         id                            title  \
# 0   980431  Avatar Aang: The Last Airbender
# 1  1632181              Accidental Partners
# 2  1007757                          Swapped
# 3      278         The Shawshank Redemption
# 4   936075                          Michael
#
#                                             overview release_date  popularity  \
# 0  Avatar Aang, the world's last Airbender, learn...   2026-07-24    231.0192
# 1  Two women discover they were both scammed by t...   2026-03-12     24.2800
# 2  A small woodland creature and a majestic bird,...   2026-05-01     64.2663
# 3  Imprisoned in the 1940s for the double murder ...   1994-09-23     75.4156
# 4  The story of Michael Jackson, one of the most ...   2026-04-22    102.8294
#
#    vote_average  vote_count
# 0         9.322         659
# 1         8.941         339
# 2         8.890        2052
# 3         8.727       30931
# 4         8.700        3855

# %%
df=pd.DataFrame()

# %%
df
# Out:
#             id                             title  \
# 0       980431   Avatar Aang: The Last Airbender
# 1      1632181               Accidental Partners
# 2      1007757                           Swapped
# 3          278          The Shawshank Redemption
# 4       936075                           Michael
# ...        ...                               ...
# 19995    19912             The Final Destination
# 19996    18998  Darkman II: The Return of Durant
# 19997    10329                             Congo
# 19998   523931                         Megalodon
# 19999   185341                 [REC]⁴ Apocalypse
#
#                                                 overview release_date  \
# 0      Avatar Aang, the world's last Airbender, learn...   2026-07-24
# 1      Two women discover they were both scammed by t...   2026-03-12
# 2      A small woodland creature and a majestic bird,...   2026-05-01
# 3      Imprisoned in the 1940s for the double murder ...   1994-09-23
# ...

# %%
for i in range(1,420):
  response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=61edce02e942091acaf4ea3adf20e348&language=en-US&page={}'.format(i))
  temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
  df = pd.concat([df, temp_df], ignore_index=True)

# %%
df.shape
# Out:
# (28380, 7)

# %%
df.to_csv('movies.csv')
